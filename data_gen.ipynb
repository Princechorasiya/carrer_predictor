# %%
import pandas as pd
import numpy as np

# Define column names
columns = [
    '10th_Math', '10th_Science', '10th_Social_Studies', '10th_English', 'Stream',
    '12th_Physics', '12th_Chemistry', '12th_Mathematics', '12th_Biology',
    '12th_History', '12th_Political_Science', '12th_Geography', '12th_Accountancy',
    '12th_Business_Studies', '12th_Economics', 'Suggested_Field', 'Interest1', 'Interest2',
    'CareerPath', 'MainJobProfiles', 'OtherJobProfiles'
]

# Example interest fields and career options
streams = ['Science', 'Commerce', 'Arts']
fields = {
    'Science': ['Engineering', 'Medical', 'Finance'],
    'Commerce': ['Chartered Accountant', 'Finance', 'Law'],
    'Arts': ['Political Science', 'History', 'Economics']
}
subfields = {
    'Engineering': ['Mechanical Engineering', 'Electrical Engineering', 'Computer Engineering', 'Civil Engineering', 'Chemical Engineering'],
    'Medical': ['MBBS', 'Pharmacy', 'Dentistry', 'Nursing', 'Public Health'],
    'Finance': ['Investment Banking', 'Financial Planning', 'Corporate Finance', 'Risk Management', 'Financial Analysis'],
    'Chartered Accountant': ['Audit', 'Taxation', 'Accounting', 'Financial Planning'],
    'Political Science': ['Public Policy', 'International Relations', 'Political Analysis', 'Government Administration'],
    'History': ['Ancient History', 'Modern History', 'Cultural History', 'Museum Studies'],
    'Economics': ['Microeconomics', 'Macroeconomics', 'Development Economics', 'International Economics'],
    'Law': ['Criminal Law', 'Corporate Law', 'Family Law', 'Human Rights Law']
}
career_paths = {
    'Mechanical Engineering': ['Mechanical Engineering Degree', 'Automotive Engineering'],
    'Electrical Engineering': ['Electrical Engineering Degree', 'Power Systems Engineering'],
    'Computer Engineering': ['Computer Engineering Degree', 'Software Engineering'],
    'Civil Engineering': ['Civil Engineering Degree', 'Structural Engineering'],
    'Chemical Engineering': ['Chemical Engineering Degree', 'Process Engineering'],
    'MBBS': ['Doctor', 'Surgeon'],
    'Pharmacy': ['Pharmacist', 'Pharmaceutical Researcher'],
    'Dentistry': ['Dentist', 'Oral Surgeon'],
    'Nursing': ['Registered Nurse', 'Nurse Practitioner'],
    'Public Health': ['Public Health Specialist', 'Epidemiologist'],
    'Investment Banking': ['Investment Banker', 'Financial Analyst'],
    'Financial Planning': ['Financial Planner', 'Wealth Manager'],
    'Corporate Finance': ['Corporate Finance Analyst', 'Finance Manager'],
    'Risk Management': ['Risk Manager', 'Insurance Analyst'],
    'Financial Analysis': ['Financial Analyst', 'Equity Analyst'],
    'Audit': ['Auditor', 'Internal Auditor'],
    'Taxation': ['Tax Consultant', 'Tax Advisor'],
    'Accounting': ['Accountant', 'Forensic Accountant'],
    'Public Policy': ['Policy Analyst', 'Public Affairs Specialist'],
    'International Relations': ['Diplomat', 'International Relations Specialist'],
    'Political Analysis': ['Political Analyst', 'Campaign Manager'],
    'Government Administration': ['Government Officer', 'City Planner'],
    'Ancient History': ['Historian', 'Archaeologist'],
    'Modern History': ['Historian', 'Museum Curator'],
    'Cultural History': ['Cultural Researcher', 'Archivist'],
    'Museum Studies': ['Museum Curator', 'Exhibit Designer'],
    'Microeconomics': ['Economist', 'Economic Consultant'],
    'Macroeconomics': ['Macroeconomist', 'Economic Researcher'],
    'Development Economics': ['Development Economist', 'Policy Advisor'],
    'International Economics': ['International Economist', 'Trade Specialist'],
    'Criminal Law': ['Criminal Lawyer', 'Public Defender'],
    'Corporate Law': ['Corporate Lawyer', 'Legal Counsel'],
    'Family Law': ['Family Lawyer', 'Divorce Attorney'],
    'Human Rights Law': ['Human Rights Lawyer', 'Advocacy Specialist']
}
main_jobs = {
    'Mechanical Engineering': ['Mechanical Engineer', 'Automotive Engineer', 'Aerospace Engineer'],
    'Electrical Engineering': ['Electrical Engineer', 'Power Systems Engineer', 'Control Systems Engineer'],
    'Computer Engineering': ['Software Engineer', 'Hardware Engineer', 'Network Engineer'],
    'Civil Engineering': ['Civil Engineer', 'Structural Engineer', 'Construction Manager'],
    'Chemical Engineering': ['Chemical Engineer', 'Process Engineer', 'Biochemical Engineer'],
    'MBBS': ['Doctor', 'Surgeon', 'General Practitioner'],
    'Pharmacy': ['Pharmacist', 'Pharmaceutical Researcher', 'Clinical Pharmacist'],
    'Dentistry': ['Dentist', 'Oral Surgeon', 'Orthodontist'],
    'Nursing': ['Registered Nurse', 'Nurse Practitioner', 'Clinical Nurse Specialist'],
    'Public Health': ['Public Health Specialist', 'Epidemiologist', 'Health Educator'],
    'Investment Banking': ['Investment Banker', 'Financial Analyst', 'Equity Trader'],
    'Financial Planning': ['Financial Planner', 'Wealth Manager', 'Insurance Advisor'],
    'Corporate Finance': ['Finance Manager', 'Financial Controller', 'Treasury Analyst'],
    'Risk Management': ['Risk Manager', 'Insurance Risk Analyst', 'Credit Risk Analyst'],
    'Financial Analysis': ['Financial Analyst', 'Investment Analyst', 'Credit Analyst'],
    'Audit': ['Auditor', 'Internal Auditor', 'Compliance Auditor'],
    'Taxation': ['Tax Consultant', 'Tax Advisor', 'Tax Preparer'],
    'Accounting': ['Accountant', 'Forensic Accountant', 'Accounting Manager'],
    'Public Policy': ['Policy Analyst', 'Public Affairs Specialist', 'Legislative Aide'],
    'International Relations': ['Diplomat', 'International Relations Specialist', 'Foreign Service Officer'],
    'Political Analysis': ['Political Analyst', 'Campaign Manager', 'Public Relations Specialist'],
    'Government Administration': ['Government Officer', 'City Planner', 'Administrative Manager'],
    'Ancient History': ['Historian', 'Archaeologist', 'Museum Curator'],
    'Modern History': ['Historian', 'Museum Curator', 'Historical Consultant'],
    'Cultural History': ['Cultural Researcher', 'Archivist', 'Ethnographer'],
    'Museum Studies': ['Museum Curator', 'Exhibit Designer', 'Collections Manager'],
    'Microeconomics': ['Economist', 'Economic Consultant', 'Market Research Analyst'],
    'Macroeconomics': ['Macroeconomist', 'Economic Researcher', 'Economic Policy Advisor'],
    'Development Economics': ['Development Economist', 'Policy Advisor', 'International Development Specialist'],
    'International Economics': ['International Economist', 'Trade Specialist', 'Global Economic Advisor'],
    'Criminal Law': ['Criminal Lawyer', 'Public Defender', 'Prosecutor'],
    'Corporate Law': ['Corporate Lawyer', 'Legal Counsel', 'Business Lawyer'],
    'Family Law': ['Family Lawyer', 'Divorce Attorney', 'Child Custody Lawyer'],
    'Human Rights Law': ['Human Rights Lawyer', 'Advocacy Specialist', 'International Human Rights Officer']
}

# Generate 100 random rows of data
data = []
for _ in range(100000):
    stream = np.random.choice(streams)
    interest1 = np.random.choice(list(subfields.keys()))
    interest2 = np.random.choice(
        [i for i in list(subfields.keys()) if i != interest1])
    suggested_field = np.random.choice(subfields[interest1])
    career_path = np.random.choice(career_paths[suggested_field])
    main_job_profile = np.random.choice(main_jobs[suggested_field])

    # Combine job options from both Interest1 and Interest2
    combined_jobs = main_jobs[suggested_field] + \
        main_jobs[np.random.choice(subfields[interest2])]

    # Ensure the sample size does not exceed the number of available jobs
    sample_size = min(5, len(combined_jobs))  # Adjust sample size as needed

    # Sample without replacement from combined jobs
    sampled_jobs = ', '.join(np.random.choice(
        combined_jobs, sample_size, replace=False))

    row = [
        np.random.randint(20, 100),  # 10th_Math
        np.random.randint(20, 100),  # 10th_Science
        np.random.randint(20, 100),  # 10th_Social_Studies
        np.random.randint(20, 100),  # 10th_English
        stream,                      # Stream
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Physics
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Chemistry
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Mathematics
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Biology
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_History
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Political_Science
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Geography
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Accountancy
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Business_Studies
        np.random.randint(20, 100) if np.random.choice(
            [True, False]) else 0,  # 12th_Economics
        suggested_field,            # Suggested_Field
        interest1,                  # Interest1
        interest2,                  # Interest2
        career_path,                # CareerPath
        main_job_profile,           # MainJobProfiles
        sampled_jobs                # OtherJobProfiles
    ]
    data.append(row)
# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Save to CSV
df.to_csv('career_recommendations.csv', index=False)
